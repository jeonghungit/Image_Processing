# %% [markdown]
# #### 데이터셋(Dataset) 다운로드 및 불러오기

# %%
import torchvision
import torchvision.transforms as transforms

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# #### ResNet18 모델 정의 및 인스턴스 초기화

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, Identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# #### 환경 설정 및 학습(Training) 함수 정의

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

net = ResNet18()
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet18_cifar10.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10
    if epoch >= 150:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# #### 학습(Training) 진행

# %% [markdown]
# * 대략 20번의 epoch 이후에도 85%가량의 test accuracy를 얻을 수 있습니다.

# %%
# for epoch in range(0, 200):
for epoch in range(0, 20):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Current batch: 0
# Current benign train accuracy: 0.078125
# Current benign train loss: 2.388375997543335
#
# Current batch: 100
# Current benign train accuracy: 0.1875
# Current benign train loss: 2.056269407272339
#
# Current batch: 200
# Current benign train accuracy: 0.4140625
# Current benign train loss: 1.6035103797912598
#
# Current batch: 300
# Current benign train accuracy: 0.375
# Current benign train loss: 1.6465762853622437
#
# Total benign train accuarcy: 33.79
# Total benign train loss: 709.0803396701813
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 44.1
# Test average loss: 0.01505603016614914
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4765625
# Current benign train loss: 1.4551249742507935
#
# Current batch: 100
# Current benign train accuracy: 0.5
# Current benign train loss: 1.3803232908248901
#
# Current batch: 200
# Current benign train accuracy: 0.515625
# Current benign train loss: 1.3816789388656616
#
# Current batch: 300
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.2407692670822144
#
# Total benign train accuarcy: 51.212
# Total benign train loss: 520.9327459335327
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 51.53
# Test average loss: 0.013782038462162019
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.1448918581008911
#
# Current batch: 100
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.1079838275909424
#
# Current batch: 200
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.1476367712020874
#
# Current batch: 300
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.074794054031372
#
# Total benign train accuarcy: 61.278
# Total benign train loss: 420.2699134349823
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 55.73
# Test average loss: 0.013257950472831726
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.095187783241272
#
# Current batch: 100
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.8443702459335327
#
# Current batch: 200
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.8454265594482422
#
# Current batch: 300
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.606478214263916
#
# Total benign train accuarcy: 68.256
# Total benign train loss: 352.13963747024536
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 54.85
# Test average loss: 0.012698512208461762
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.8412008881568909
#
# Current batch: 100
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8402146100997925
#
# Current batch: 200
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.8413206934928894
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6744326949119568
#
# Total benign train accuarcy: 72.404
# Total benign train loss: 306.52962493896484
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 71.69
# Test average loss: 0.008258301734924317
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.7089037895202637
#
# Current batch: 100
# Current benign train accuracy: 0.7578125
# Current benign train loss: 0.685465395450592
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5612273216247559
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5870563983917236
#
# Total benign train accuarcy: 76.116
# Total benign train loss: 268.1968670785427
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 70.58
# Test average loss: 0.008628885054588318
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6949350237846375
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.483119934797287
#
# Current batch: 200
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5433222651481628
#
# Current batch: 300
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6112284064292908
#
# Total benign train accuarcy: 79.374
# Total benign train loss: 232.8073067367077
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 78.13
# Test average loss: 0.006473048356175423
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.48917466402053833
#
# Current batch: 100
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.65577232837677
#
# Current batch: 200
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.6013448238372803
#
# Current batch: 300
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4814930856227875
#
# Total benign train accuarcy: 81.3
# Total benign train loss: 210.7352160513401
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 79.14
# Test average loss: 0.006108805128931999
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5439281463623047
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.48162853717803955
#
# Current batch: 200
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.44673943519592285
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.46902206540107727
#
# Total benign train accuarcy: 83.124
# Total benign train loss: 191.74564376473427
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 81.49
# Test average loss: 0.005283053550124169
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4788300395011902
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.42461833357810974
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.42032521963119507
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5378103852272034
#
# Total benign train accuarcy: 84.128
# Total benign train loss: 179.58348578214645
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 80.99
# Test average loss: 0.0055982914000749584
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3939270079135895
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5414209365844727
#
# Current batch: 200
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3693835735321045
#
# Current batch: 300
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.46080470085144043
#
# Total benign train accuarcy: 85.336
# Total benign train loss: 166.43056519329548
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 79.95
# Test average loss: 0.005924048319458961
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.35049721598625183
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3760417699813843
#
# Current batch: 200
# Current benign train accuracy: 0.875
# Current benign train loss: 0.29961633682250977
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.5596602559089661
#
# Total benign train accuarcy: 86.06
# Total benign train loss: 155.15527738630772
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 80.34
# Test average loss: 0.005931092992424965
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5083947777748108
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5034959316253662
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5187866687774658
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5142340064048767
#
# Total benign train accuarcy: 86.954
# Total benign train loss: 146.54295100271702
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 81.16
# Test average loss: 0.0060399930953979495
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.43551144003868103
#
# Current batch: 100
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.30467626452445984
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4378301799297333
#
# Current batch: 300
# Current benign train accuracy: 0.875
# Current benign train loss: 0.4350462555885315
#
# Total benign train accuarcy: 87.684
# Total benign train loss: 139.8530933558941
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 84.18
# Test average loss: 0.004673660251498222
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3099507987499237
#
# Current batch: 100
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3274170160293579
#
# Current batch: 200
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.515044093132019
#
# Current batch: 300
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.37707769870758057
#
# Total benign train accuarcy: 88.284
# Total benign train loss: 133.18647998571396
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 81.65
# Test average loss: 0.0056264681249856945
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.39106088876724243
#
# Current batch: 100
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.38310331106185913
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.2988448143005371
#
# Current batch: 300
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.3079432249069214
#
# Total benign train accuarcy: 88.684
# Total benign train loss: 129.14421051740646
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 81.19
# Test average loss: 0.005426435428857804
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.27559107542037964
#
# Current batch: 100
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.27430230379104614
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.32400691509246826
#
# Current batch: 300
# Current benign train accuracy: 0.875
# Current benign train loss: 0.33999812602996826
#
# Total benign train accuarcy: 89.24
# Total benign train loss: 122.59602874517441
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 82.02
# Test average loss: 0.005548394346237183
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.443058580160141
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.33609896898269653
#
# Current batch: 200
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.25249847769737244
#
# Current batch: 300
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.35391655564308167
#
# Total benign train accuarcy: 89.482
# Total benign train loss: 118.42120113968849
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 84.37
# Test average loss: 0.004802022659778595
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.25706928968429565
#
# Current batch: 100
# Current benign train accuracy: 0.875
# Current benign train loss: 0.4054352641105652
#
# Current batch: 200
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2669866681098938
#
# Current batch: 300
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2903689444065094
#
# Total benign train accuarcy: 89.704
# Total benign train loss: 117.39217266440392
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 82.71
# Test average loss: 0.005547811171412468
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.18217258155345917
#
# Current batch: 100
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.18327756226062775
#
# Current batch: 200
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.33784452080726624
#
# Current batch: 300
# Current benign train accuracy: 0.875
# Current benign train loss: 0.32198768854141235
#
# Total benign train accuarcy: 89.918
# Total benign train loss: 112.65335751324892
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 84.05
# Test average loss: 0.0049544367671012874
# Model Saved!
